# %% [markdown]
# <font size=5><b>Air Pollution Case Study </b></font>
# ***

# %% [markdown]
# <font size=3><b>Context</b></font><br><br>
# Air pollution is all around us. Indoors, outdoors, in cities, and in the countryside. It affects us all, whether we realize it or not. The rise in permissible concentrations of various pollutants observed over the last few decades contributes to rising pollution levels. As a result, they affect the weather conditions in an unfavorable manner and the formation of smog phenomena. The affected air quality level in the atmosphere harms individual health and may cause an economic imbalance. Diseases caused by rising pollution levels are significant issues confronting urban settlements.
#
# In this case study, we will explore and visualize the Air Pollution dataset, which contains information about air molecules and pollutants found in the air.

# %% [markdown]
# <font size=3><b>Objective</b></font><br><br>
# This problem aims to reduce the number of features by using dimensionality reduction techniques such as PCA and t-SNE and extract insights about the data.

# %% [markdown]
# <font size=3><b>Dataset</b></font><br>
# <ul>
#     <li>This dataset contains approximately <b>13 months of data on major pollutants and meterological levels of a city</b>.</li>
#     <li>The data shows average readings for Nitric Oxide(NO), Nitrogen Dioxide(NO2), Oxides of Nitrogen, Ozone, Particulate Matter(PM10 and PM2.5), Sulphur Dioxide, Benzene, Toulene, and P_Xylene, all measured in Micrograms per Cubic Meter of Air(ug/m3). It also shows a few generic features WindSpeed, VerticalWindSSpeed, BarPressure, Weather, Temperature, and WindDirection.</li>
#     <li>The PD denotes the Previous Day. In this dataset, we have five previous date values of corresponding columns in the dataset. They are PD_PM10, PD_NO2, PD_SO2, PD_CO, PD_PM2.5.</li>
#     <li>The <b>Date</b> is the feature at which the data was recorded.</li>

# %% [markdown]
# <font size=3><b>Importing the libraries and overview of the dataset</b></font><br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# To scale the data using z-score
from sklearn.preprocessing import StandardScaler

# Import PCA and t-SNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# Library to suppress warnings, don't make a practice of using it, it's bad practice
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <font size=3><b>Left justify and tables that may be used.</b></font><br>

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# <font size=3><b>Get an overview of the data and prepare it for visualization</b></font>

# %%
# Loading the data
data_air_pol = pd.read_csv("AirPollution.csv")

# %%
data_air_pol.head()
# Out:
#    SrNo        Date    NO    CO    NO2     O3    SO2   PM2.5  Benzene  \
# 0     1  04-04-2015  7.22  1.77  47.94  51.07  16.88   48.99     2.53
# 1     2  05-04-2015  6.99  0.22  45.27  19.26  16.71   60.20     3.19
# 2     3  09-04-2015  7.60  0.50  59.86  94.29  13.11   46.93     2.29
# 3     4  10-04-2015  7.57  0.77  63.56  66.91  16.19  112.95     3.92
# 4     5  11-04-2015  8.34  0.48  61.99  69.48  20.28  104.87     5.19
#
#    Toulene  ...  WindSpeed  VerticalWindSpeed   Solar  BarPressure  Weather  \
# 0     9.65  ...       1.22               0.08  162.18       732.25   Summer
# 1    11.10  ...       0.62              -0.04   99.37       734.05   Summer
# 2     8.61  ...       1.55              -0.17  146.94       728.08   Summer
# 3    10.76  ...       1.18              -0.15  150.07       730.47   Summer
# 4    15.95  ...       0.88               0.15  137.01       730.62   Summer
#
#    PD_PM2.5  PD_PM10  PD_NO2  PD_SO2  PD_CO
# ...

# %% [markdown]
# <font size=3><b>Checking the info of the data</b></font>

# %%
data_air_pol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SrNo               403 non-null    int64
#  1   Date               403 non-null    object
#  2   NO                 401 non-null    float64
#  3   CO                 402 non-null    float64
#  4   NO2                401 non-null    float64
#  5   O3                 397 non-null    float64
#  6   SO2                399 non-null    float64
#  7   PM2.5              401 non-null    float64
#  8   Benzene            402 non-null    float64
#  9   Toulene            402 non-null    float64
#  10  P_Xylene           372 non-null    float64
#  11  NOx                401 non-null    float64
#  12  PM10               401 non-null    float64
#  13  WindDirection      402 non-null    float64
#  14  NH3                401 non-null    float64
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     <ul>
#         <li>There are <b>403 observations and 27 columns</b> in the data.</li>
#         <li><b>All the columns except Date and Weather are of numeric data type</b>.</li>
#         <li>The <b>Date and SrNo for all observations would be unique. We can drop these columns</b> as they would not add value to our analysis.</li>
#         <li>Weather is of object data type. We can create <b>dummy variables</b> for each category and convert it to numeric data type.</li>
#         <li>The majority of the <b>columns have some missing values</b>
#     </ul>
# </div>

# %% [markdown]
# <font size=3><b>Let's check the number of missing values in each column.</b></font>

# %%
data_air_pol.isnull().sum()
# Out:
# SrNo                  0
# Date                  0
# NO                    2
# CO                    1
# NO2                   2
# O3                    6
# SO2                   4
# PM2.5                 2
# Benzene               1
# Toulene               1
# P_Xylene             31
# NOx                   2
# PM10                  2
# WindDirection         1
# NH3                   2
# RH                    1
# Temp                  2
# WindSpeed             1
# VerticalWindSpeed     2
# Solar                 2
# BarPressure           2
# Weather               0
# PD_PM2.5             10
# PD_PM10              11
# PD_NO2               12
# PD_SO2               13
# PD_CO                11
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     <ul>
#         <li>All the columns except SrNo and Date have missing values.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size = 4><b>Note:</b></font>
#     <ul>
#         <li>Mean and Median may be good choices for missing columns of numerical data.</li>
#         <ul>
#             <li><b>Mean</b> for <b>not normally distributed</b> data.</li>
#             <li><b>Median</b> for <b>highly skewed</b> data.</li>
#         </ul>
#         <li>Mode is a good choice for categorial variables.</li>
#         <li>In this scenario, we could use the previous day's values, but futher analysis would be needed to determine if there are correlations present with the previous day and the present day</li>
#         <li> Best practice is to <b>NOT DROP NULL VALUES</b>
#     </ul>
# </div>

# %% [markdown]
# <font size=3><b>Impute (fill in) these missing values by using the mode for the categorical variables and the median for the numerical ones.</b></font>

# %% [markdown]
# <font size=3><b>Summary Statistics</b></font>

# %%
data_air_pol.describe().T
# Out:
#                    count        mean         std     min       25%      50%  \
# SrNo               403.0  202.000000  116.480327    1.00  101.5000  202.000
# NO                 401.0   81.323292   97.204368    1.12   11.3800   39.220
# CO                 402.0    2.210000    1.601589    0.22    1.2025    1.780
# NO2                401.0   74.433791   25.862319   25.27   54.5000   73.680
# O3                 397.0   56.298917   29.690436    4.98   30.1200   53.210
# SO2                399.0   25.988496   25.273204    0.00    9.5150   21.680
# PM2.5              401.0  130.160673   84.196954   18.75   68.1100  108.240
# Benzene            402.0    6.525945    3.983177    0.16    3.2350    5.910
# Toulene            402.0   17.192488   10.410131    0.00    9.6950   16.240
# P_Xylene           372.0    8.128844    6.733961    0.30    3.3825    6.060
# NOx                401.0  194.681222  141.121196   26.49   87.6700  152.310
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size = 4><b>Note:</b></font><br><br>In the chart above, you can go the extra mile by looking up the healthly or acceptible ranges for these pollutants. You could impute these ranges as separate columns an calculate exact percentages. Spend some time, a few minutes, staring at the data above to see if anything jumps out at you. Most new and inexperienced data scientists today skip this.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     <ul>
#         <li>The normal level of PM10 is about 100 micrograms per cubic meter and the PM2.5 is about 60 micrograms per cubic meter. Here, we can infer that PM10 has a high median of ~250 and PM2.5 has a median of 108, which are harmful to the environment and people.</li>
#         <li>The higher level of different types of particulate matter indicates that the data might belong to an urban or industrial area.</li>
#         <li>The concetration of Nitrogen Oxide (NO) in the air should be in a range from 60 to 80µg/$m^{3}$. The mean of Nitrogen Oxide is 74.4, which is in the given range ensuring less impact.</li>
#         <li>The standard deviation is very high for the variables - NO, NO$m_{x}$, PM10, and PM2.5 indicating that the pollution varies highly in a year as the data is for 13 months.</li>
#         <li>The maximum value of many features reaches an alarming high-level, indicating there might be outliers in the data.</li>
#     </ul>
# </div>

# %% [markdown]
# <font size=3><b>Let's check the distribution and outliers for numerical columns in the data.</b></font>

# %%
result = data_air_pol.select_dtypes(include = 'number')
cont_cols = list(result)
for col in cont_cols:
    print(col)
    print('Skew:',round(data_air_pol[col].skew(),2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data_air_pol[col].hist(bins = 10, grid = False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x = data_air_pol[col])
    plt.show()
# Out:
# SrNo
# Skew: 0.0
# NO
# Skew: 1.65
# CO
# Skew: 4.16
# NO2
# Skew: 0.35
# O3
# Skew: 0.53
# SO2
# Skew: 6.87
# PM2.5
# Skew: 1.45
# Benzene
# Skew: 0.71
# Toulene
# Skew: 0.61
# P_Xylene
# Skew: 1.55
# NOx
# Skew: 1.32
# PM10
# Skew: 0.61
# WindDirection
# Skew: -0.49
# NH3
# Skew: 1.34
# RH
# Skew: -0.36
# Temp
# Skew: -0.57
# WindSpeed
# Skew: 0.9
# VerticalWindSpeed
# Skew: 0.86
# Solar
# Skew: 0.15
# BarPressure
# Skew: -1.96
# PD_PM2.5
# Skew: 1.44
# PD_PM10
# Skew: 0.6
# PD_NO2
# Skew: 0.36
# PD_SO2
# Skew: 6.9
# PD_CO
# Skew: 4.26

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     <ul>
#         <li>The distribution plots show that PD_CO, PD_SO2, NH3, PD_PM2.5, NO$m_{x}$, P_Xylene, and PM2.5 variables are highly right-skewed. It is evident for the boxplots that all these variables have outliers to the right</li>
#         <li>RH, Temp, WindDirection, and BarPressure are left-skewed with BarPressure having the only indication of outliers</li>
#         <li>Benezene, Toulene, PM10, PD_PM10, VerticalWindSpeed, and WindSpeed seem to have a moderate righ skew</li>
#     </ul>
# </div>

# %% [markdown]
# <font size=3><b>Let's check the correlation among different variables</b></font>

# %%
plt.figure(figsize = (18,12))
sns.heatmap(data_air_pol.corr(), annot = True, fmt = '0.2f')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size = 4><b>Note:</b></font><br><br>In the chart above, you can use business contacts, measurements, or talk to experts to help review the reduction data. These are all widely used.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     <ul>
#         <li>We can see a <b> high positive correlation</b> among the following variables:
#             <ol>
#                 <li>NO2 and PD_NO2</li>
#                 <li>PM2.5 and PD_PM2.5</li>
#                 <li>PM10 and PD_PM2.5</li>
#                 <li>PD_PM10 and PD_PM2.5</li>
#             </ol><br>
#         <li>We can see a <b>high negative correlation</b> among the following variables:
#             <ol>
#                 <li>Temp and NO2</li>
#                 <li>VerticalWindSpeed and PD_SO2</li>
#                 <li>VerticalWindSpeed and PD_PM2.5</li>
#                 <li>WindDirection and VerticalWindSpeed</li>
#                 <li>SO2 and WindSpeed</li>
#             </ol><br>
#         <li>Nitrates and fine particulate matter 2.5(PM2.5) are positively correlated with their previous day values (PD_NO2 and PD_PM2.5) which makes sense.</li>
#         <li>Particulate matter of 2.5 micrometers in diameter is positively correlated with the Particle matter of 10 micrometers in diameter.</li>
#         <li>Temp and NO2 are negatively correlated which makes sense as nitrate molecules in the air increase and the temperature decreases.</li>
#         <li>Since the WindSpeed and VerticleWindSpeed are negatively correlated to pollutants like PD_SO2 and PD_PM2.5. This makes sense as higher wind speeds generally translate to a greater dispersion of air pollutants, resulting in lower air pollution concentrations in areas with stronger winds.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size = 4><b>Note: Need For Dimensionality Reduction</b></font><br><br>
#         <ul>
#             <li>Dimensionality reduction is the process to reduce the number of dimensions in the feature space.</li>
#             <ul>
#                 <li>A <b>feature = column = dimension</b>, meaning they are the same.</li>
#             </ul>
#             <li>In machine learning, we tend to add many features to get more accurate results. However, after a certain point, the performance and robustness of the model start decreasing and the computational complexity starts increasing as we increase the number of features. This is called <b>The Curse of Dimensionality</b> where the sample density decreases exponentially with the increase of dimensionality.</li>
#             <ul>
#                 <li>We use dimentionality reduction to transform the data into low dimensions while keeping most of the information intact.</li>
#                 <li>It also helps us to visualize the high-dimensional data in 2D and 3D.</li>
#                 <li><b>The curse is with more features|columns|dimesion the harder it becomes to draw insights and machine learning becomes less effective.</b>
#             </ul>
#             <li>There are the following techniques we can use for dimensionality reduction:</li>
#             <ul>
#                 <li><b>Principal Component Analysis (PCA)</b> - is a dimensionality reduction technique used for the identifation of a smaller number of uncorrelated variables knowns as principal compenents from a larger dataset. This technique is widely used to <b>emphasize variation and caputure strong patterns in a dataset</b>. PCA requires two properties to be true:</li>
#                 <ul>
#                     <li>The two variables must have a linear correlation</li>
#                     <li>The two variables must be on the same scale</li>
#                 </ul>
#                 <li><b>t-distributed stochastic neighbor embedding (t-SNE)</b> is a technique for dimensionality reduction that is well suited for <b>visualization of high-dimensional datasets.</b></li>
#                 <ul>
#                     <li>This is not a clustering technique</li>
#                 </ul>
#             </ul>
#     </ul>
#     <img style="float: left;" src="featurespacetran.png" width="600" height="700">
# </div>

# %% [markdown]
# <font size=3><b>More about PCA</b></font>
#
# https://setosa.io/ev/principal-component-analysis/

# %% [markdown]
# <font size=3><b>Data Preprocessing</b></font>

# %%
# Dropping the columns - SrNo and Date
data_air_pol.drop(columns = ["SrNo", "Date"], inplace = True)

# %%
# Imputing missing values with mode for the Weather column and with median for all other columns
for col in data_air_pol.columns:
    
    if col == "Weather":
        data_air_pol[col].fillna(value = data_air_pol[col].mode()[0], inplace = True)
    
    else:
        data_air_pol[col].fillna(value = data_air_pol[col].median(), inplace = True)

# %%
# Creating dummy variables for Weather column
data_air_pol = pd.get_dummies(data_air_pol, drop_first = True)

# %% [markdown]
# <font size=3><b>Scaling the data</b></font>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size = 4><b>Note:</b></font><br><br>Before starting machine learning, you have to scale the data.</div>

# %%
scaler = StandardScaler()
data_air_pol_scaled = scaler.fit_transform(data_air_pol)

# %%
data_air_pol_scaled = pd.DataFrame(data_air_pol_scaled, columns = data_air_pol.columns)

# %% [markdown]
# <font size=3><b>Principal Component Analysis (PCA)</b></font>

# %%
# Defining the number of principal components to generate
n = data_air_pol_scaled.shape[1]

# Finding principal components for the data
pca1 = PCA(n_components = n, random_state = 1)
data_air_pol_pca = pd.DataFrame(pca1.fit_transform(data_air_pol_scaled))

# The percentage of variance explained by each principal component
exp_var1 = pca1.explained_variance_ratio_

# %%
# Visualize the explained variance by individual components
plt.figure(figsize = (10, 10))

plt.plot(range(1, 29), pca1.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')

plt.title("Explained Variances by Components")

plt.xlabel("Number of Components")

plt.ylabel("Cumulative Explained Variance")

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size = 4><b>Note:</b></font><br><br>The chart above is telling you that two columns is about 40% of the data. That's decent, but you want to go higher, for example 80% (.8) on the left. For example, the 5 (components) at the bottom represent just over 70% of the data. If you use 5 that means PCA reduced your 27 colums/features to 5 and it covers 70 percent of the data.</div>

# %%
# Find the least number of components that can explain more than 70% variance
sum = 0

for ix, i in enumerate(exp_var1):
    
    sum = sum + i
    
    if(sum>0.70):
        print("Number of PCs that explain at least 70% variance: ", ix + 1)
        break
# Out:
# Number of PCs that explain at least 70% variance:  5

# %%
# Making a new dataframe with first 5 principal components as columns and original features as indices
cols = ['PC1', 'PC2', 'PC3', 'PC4', 'PC5']

pc1 = pd.DataFrame(np.round(pca1.components_.T[:, 0:5], 2), index = data_air_pol_scaled.columns, columns = cols)

# %%
pc1
# Out:
#                     PC1   PC2   PC3   PC4   PC5
# NO                 0.25 -0.05  0.18  0.14 -0.13
# CO                 0.21  0.04  0.18 -0.00 -0.03
# NO2                0.19 -0.22  0.18  0.06  0.24
# O3                 0.02 -0.38 -0.02  0.18  0.08
# SO2                0.12 -0.19 -0.20  0.28 -0.11
# PM2.5              0.26 -0.06 -0.10 -0.18 -0.14
# Benzene            0.27  0.09  0.15  0.01 -0.01
# Toulene            0.25  0.10  0.27  0.08  0.01
# P_Xylene           0.25  0.07  0.22  0.03 -0.10
# NOx                0.24  0.01  0.26  0.15 -0.12
# PM10               0.23 -0.17 -0.10 -0.16 -0.20
# WindDirection      0.09 -0.06  0.03  0.13 -0.56
# NH3                0.24  0.04 -0.12 -0.08  0.11
# RH                 0.10  0.46 -0.02  0.01  0.18
# Temp              -0.21 -0.17  0.30 -0.06 -0.20
# WindSpeed         -0.20 -0.04 -0.27 -0.07 -0.07
# VerticalWindSpeed -0.03 -0.22  0.28 -0.20  0.31
# Solar             -0.18 -0.22  0.14  0.11 -0.27
# BarPressure        0.13 -0.01 -0.29  0.27 -0.06
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <font size = 3><b>Note: How to explain the numbers above</b></font><br><br>
#     The industrial gases, some particulate matter, and Nitric Oxide (NO) form a group of features that all provide similar information that was condensed into one principal component. What do I mean my condensed? In the data above there are 27 columns, also referred to as features. Two features for a two-dimensional grid, three features is three-dimensional. There are 27 features meaning this is multidentional data. The technique, PCA, used for the identifation of a smaller number of uncorrelated variables knowns as principal compenents from a larger dataset. This allows us to reduce the dimensions while keeping the information intact.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     <ol>
#         <li>The first principal component, PC1, seems to be related to hydrocarbons like Benzene, Toluene, and Xylene that are generated due to fuel combustion.</li>
#         <li>The second principal component, PC2, seems to be related to humidity (RH), Ozone level, and rain, i.e., the rainy season. Whenever humidity goes down, the Ozone level goes up - more sunshine. Higher humidity is an indication of rain which has the potential to wash away atmospheric pollution.</li>
#         <li>The third principal component, PC3, seems to be capturing air pressure - low pressure accompanies windy and rainy conditions, dispersing the pollution away. High pressure stills the wind allowing pollution to build up in urban areas.</li>
#         <li>The fourth principal component, PC4, seems to be associated with high values of toxic gases like SO2 and is also related to the weather.</li>
#         <li>The fifth principal component, PC5, seems to be explaining the direction of the wind which impacts air pollution irrespective of the concentration of all pollutants. If the wind is blowing towards an urban area from an industrial area then pollution levels are likely to be higher in the town or city than if the air is blowing from another direction, for example, open farmland.</li>
#     </ol>
# </div>

# %% [markdown]
# <font size=4><b>t-distributed stochastic neighbor embedding (t-SNE)</b></font>

# %% [markdown]
# <font size=3><b>More about t-SNE</b></font>
#
# https://distill.pub/2016/misread-tsne/

# %% [markdown]
# <font size=3><b>Let's try to visualize the data for different perplexity values.</b></font>

# %%
for i in range(10, 50, 5):
    print(i)
    tsne = TSNE(n_components = 2, random_state = 1, perplexity = i)
    
    data_air_pol_tsne = tsne.fit_transform(data_air_pol_scaled)
    
    data_air_pol_tsne = pd.DataFrame(data_air_pol_tsne)
    
    data_air_pol_tsne.columns = ['X1', 'X2']
    
    plt.figure(figsize = (7,7))
    
    sns.scatterplot(x = 'X1', y = 'X2', data = data_air_pol_tsne)
    
    plt.title("perplexity = {}".format(i))
# Out:
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     <ul>
#         <li>We can clearly see <b>4 groups in the data</b>.</li>
#     </ul>
# </div>

# %% [markdown]
# <font size=3><b>Let's label these 4 groups using the values of the X1 and X2 axes.</b></font>

# %%
# Let's assign points to 4 different groups
def grouping(x):
    first_component = x['X1']
    
    second_component = x['X2']
    
    if second_component > 12:
        return 'group_1'
    
    elif (second_component < -10) and (first_component > -10): 
        return 'group_2'
    
    elif (second_component < 12) and (first_component > -9):
        return 'group_3'
    
    else: 
        return 'group_4'

# %%
data_air_pol_tsne['groups'] = data_air_pol_tsne.apply(grouping, axis = 1)

# %%
# Scatter plot for two components with hue
plt.figure(figsize = (7, 7))

sns.scatterplot(x = 'X1', y = 'X2', data = data_air_pol_tsne, hue = 'groups')
# Out:
# <AxesSubplot:xlabel='X1', ylabel='X2'>

# %%
data_air_pol_scaled.columns[:-4].tolist()
# Out:
# ['NO',
#  'CO',
#  'NO2',
#  'O3',
#  'SO2',
#  'PM2.5',
#  'Benzene',
#  'Toulene',
#  'P_Xylene',
#  'NOx',
#  'PM10',
#  'WindDirection',
#  'NH3',
#  'RH',
#  'Temp',
#  'WindSpeed',
#  'VerticalWindSpeed',
#  'Solar',
#  'BarPressure',
#  'PD_PM2.5',
#  'PD_PM10',
#  'PD_NO2',
#  'PD_SO2',
#  'PD_CO']

# %% [markdown]
# <font size=3><b>Now, let's try to visualize the properties of these four groups with respect to all the numeric variables in the data.</font>

# %%
all_col = data_air_pol_scaled.columns[:-4].tolist()

plt.figure(figsize = (14, 40))

for i, variable in enumerate(all_col):
    plt.subplot(8, 3, i + 1)
    
    sns.boxplot(y=data_air_pol_scaled[variable], x=data_air_pol_tsne['groups'])
    
    plt.tight_layout()
    
    plt.title(variable)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size=4 color=black><b>Observations:</b></font><br>
#     There are four groups in the data. Each group has a different set of characteristics.
#     <ul>
#         <li><b>Group 1 represents hot and humid areas</b>. As there is less variability in the pressure, the wind speed is low. Higher humidity is an indication of rain which has the potential to wash away atmospheric pollution, resulting in low levels of pollutants - fine particulate matter and hydrocarbons.</li>
#         <li>Group 2 represents areas with medium humidity and temperature with low pressure and wind speed. The level of pollutants is medium. These might be <b>developing urban areas</b> where the Ozone (O3) concentration is medium to high, resulting in comparatively higher solar radiation.</li>
#         <li>Group 3 is the largest and represents low-humidity and high-temperature areas. As the variability in pressure is high, the wind speed is high. If the wind is blowing towards an urban area from an industrial area then pollution levels are likely to be higher in the town or city than if the air is blowing from another direction, for example, open farmland. These might be <b>developed urban areas</b> as they have the highest level of Ozone pollutant and solar radiation, which could be a result of pollutants emitted by cars, power plants, etc.</li>
#         <li>Group 4 represents <b>industrial areas</b> as it has a very high concentration of hydrocarbons, which are generally a result of fuel combustion. These areas have a high level of fine particulate matter and other pollutants. As there is less variability in air pressure, the wind speed is low.</li>
#     </ul>
# </div>
